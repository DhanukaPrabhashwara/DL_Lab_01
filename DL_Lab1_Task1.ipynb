# %% [markdown]
# <a href="https://colab.research.google.com/github/DhanukaPrabhashwara/DL_Lab_01/blob/main/DL_Lab1_Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing Libraries
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import pandas as pd

# %% [markdown]
# Create a random 4x4 array from an exponential distribution.

# %%
exp_array = np.random.exponential(scale=1.0, size=(4, 4))
print(exp_array)
# Out:
# [[0.97635612 1.20272856 0.38107338 1.62262324]
#  [1.82173508 0.41609916 1.25469058 0.50805446]
#  [0.95895283 5.30281272 1.19176003 1.2819613 ]
#  [4.68000622 0.12229314 1.83464035 0.46837628]]

# %% [markdown]
# Create a random 100000x1 array from the same exponential distribution and visualize the
# distribution histogram along with uniform and normal distributions.

# %%
# Arrays
exp_data = np.random.exponential(scale=1.0, size=(100000,))
uni_data = np.random.rand(100000)
norm_data = np.random.randn(100000)

# %%
# Histogram Plot
plt.hist(exp_data, bins=100, density=True, histtype='step', color='red', label='Exponential')
plt.hist(uni_data, bins=100, density=True, histtype='step', color='blue', label='Uniform')
plt.hist(norm_data, bins=100, density=True, histtype='step', color='green', label='Normal')

plt.axis([-2.5, 10, 0, 1.5])
plt.legend(loc='upper right')
plt.title("Random Distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %% [markdown]
#  Plot the Z = X**2 + Y**2 in a 3D plot. Limit the x and y values to [-5, 5].

# %%
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)

X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2

# Create a 3D plot
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

surface = ax.plot_surface(X, Y, Z, cmap='viridis')

ax.set_title('Z = X² + Y²')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')

plt.show()
